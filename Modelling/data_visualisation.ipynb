# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("../Dataset/loan_dataset.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     5000 non-null   int64
#  1   ID             5000 non-null   int64
#  2   Pin-code       5000 non-null   int64
#  3   age            5000 non-null   int64
#  4   Fam members    5000 non-null   float64
#  5   Education      5000 non-null   object
#  6   T.Experience   5000 non-null   float64
#  7   Income         5000 non-null   int64
#  8   Mortgage       5000 non-null   int64
#  9   Fixed Deposit  5000 non-null   object
#  10  Demat          5000 non-null   object
#  11  Net Banking    5000 non-null   object
#  12  Loan           5000 non-null   object
# dtypes: float64(2), int64(6), object(5)
# memory usage: 507.9+ KB

# %%
data.head()
# Out:
#    Unnamed: 0     ID  Pin-code  age  Fam members       Education  \
# 0           0  10001    110001   23          4.0  Under Graduate
# 1           1  10002    110014   43          3.0  Under Graduate
# 2           2  10003    110014   37          1.0  Under Graduate
# 3           3  10004    110003   33          1.0        Graduate
# 4           4  10005    110004   33          4.0        Graduate
#
#    T.Experience  Income  Mortgage Fixed Deposit Demat Net Banking Loan
# 0           1.0  392000         0            no   yes          no   no
# 1          19.0  272000         0            no   yes          no   no
# 2          15.0   88000         0            no    no          no   no
# 3           9.0  800000         0            no    no          no   no
# 4           8.0  360000         0            no    no          no   no

# %%
#dropping unecessary columns
data = data.drop(['Unnamed: 0'],axis=1)
data
# Out:
#             ID  Pin-code  age  Fam members       Education  T.Experience  \
# 0        10001    110001   23          4.0  Under Graduate           1.0
# 1        10002    110014   43          3.0  Under Graduate          19.0
# 2        10003    110014   37          1.0  Under Graduate          15.0
# 3        10004    110003   33          1.0        Graduate           9.0
# 4        10005    110004   33          4.0        Graduate           8.0
# ...        ...       ...  ...          ...             ...           ...
# 4995  10004996    110014   27          1.0   Post Graduate           3.0
# 4996  10004997    110004   28          4.0  Under Graduate           4.0
# 4997  10004998    110014   61          2.0   Post Graduate          39.0
# 4998  10004999    110003   63          3.0        Graduate          40.0
# 4999  10005000    110001   26          3.0  Under Graduate           4.0
#
#       Income  Mortgage Fixed Deposit Demat Net Banking Loan
# ...

# %%
#used to find if the data has any duplicated values - the field used is ID, which is unique to every row
print(data.duplicated(["ID"]).sum())

#below counts the occurnance of unique elements
unique = data["ID"].value_counts()
print(unique.sum())
# Out:
# 0
# 5000

# %% [markdown]
# ## Missing Values Computation
#
# In given data, there can exist missing values due to various reason.
# The columns that might have potential misisng values are:
# - Pin Code
# - Age
# - Fam members
# - T.Experience
# - Income
# - Mortgage

# %%
cont_data = data.select_dtypes([int,float])

# %%
cont_data.isnull().sum()
# Out:
# ID              0
# Pin-code        0
# age             0
# Fam members     0
# T.Experience    0
# Income          0
# Mortgage        0
# dtype: int64

# %% [markdown]
# There exists no misisng values in the given data.
#
# Now lets compute missing values for categorical data.

# %%
cat_data = data.select_dtypes(object)

# %%
cat_data.isnull().sum()
# Out:
# Education        0
# Fixed Deposit    0
# Demat            0
# Net Banking      0
# Loan             0
# dtype: int64

# %% [markdown]
# There exists no missing values in the given data.
#
# ### There exists no duplicates or no catergorical or continues missing values
#
# ## Outlier Analysis

# %% [markdown]
# ## Visualising the Data

# %%
sns.pairplot(data,)
